# %%
import pandas as pd
data=pd.read_excel("C:/Users/ayush/Desktop/TE Practical Exam/DSBDA/Q2/AirQualityUCI.xlsx")

# %%
data
# Out:
#            Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  \
# 0    2004-03-10  0.750000     2.6      1360.00       150  11.881723
# 1    2004-03-10  0.791667     2.0      1292.25       112   9.397165
# 2    2004-03-10  0.833333     2.2      1402.00        88   8.997817
# 3    2004-03-10  0.875000     2.2      1375.50        80   9.228796
# 4    2004-03-10  0.916667     1.6      1272.25        51   6.518224
# ...         ...       ...     ...          ...       ...        ...
# 9352 2005-04-04  0.416667     3.1      1314.25      -200  13.529605
# 9353 2005-04-04  0.458333     2.4      1162.50      -200  11.355157
# 9354 2005-04-04  0.500000     2.4      1142.00      -200  12.374538
# 9355 2005-04-04  0.541667     2.1      1002.50      -200   9.547187
# 9356 2005-04-04  0.583333     2.2      1070.75      -200  11.932060
#
#       PT08.S2(NMHC)  NOx(GT)      predict  accuracy  PT08.S3(NOx)  NO2(GT)  \
# 0           1045.50    166.0  7415.878788  2.238440       1056.25    113.0
# 1            954.75    103.0  4619.060606  2.229891       1173.75     92.0
# 2            939.25    131.0  5862.090909  2.234698       1140.00    114.0
# 3            948.25    172.0  7682.242424  2.238930       1092.00    122.0
# 4            835.50    131.0  5862.090909  2.234698       1205.00    116.0
# ...             ...      ...          ...       ...           ...      ...
# 9352        1101.25    471.7          NaN       NaN        538.50    189.8
# 9353        1027.00    353.3          NaN       NaN        603.75    179.2
# 9354        1062.50    293.0          NaN       NaN        603.25    174.7
# 9355         960.50    234.5          NaN       NaN        701.50    155.7
# 9356        1047.25    265.2          NaN       NaN        654.00    167.7
#
#       PT08.S4(NO2)  PT08.S5(O3)       T         RH        AH
# 0          1692.00      1267.50  13.600  48.875001  0.757754
# 1          1558.75       972.25  13.300  47.700000  0.725487
# 2          1554.50      1074.00  11.900  53.975000  0.750239
# 3          1583.75      1203.25  11.000  60.000000  0.786713
# 4          1490.00      1110.00  11.150  59.575001  0.788794
# ...            ...          ...     ...        ...       ...
# 9352       1374.25      1728.50  21.850  29.250000  0.756824
# 9353       1263.50      1269.00  24.325  23.725000  0.711864
# 9354       1240.75      1092.00  26.900  18.350000  0.640649
# 9355       1041.00       769.75  28.325  13.550000  0.513866
# 9356       1128.50       816.00  28.500  13.125000  0.502804
#
# [9357 rows x 17 columns]

# %%
data.dropna()
# Out:
#         Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  \
# 0 2004-03-10  0.750000     2.6      1360.00       150  11.881723
# 1 2004-03-10  0.791667     2.0      1292.25       112   9.397165
# 2 2004-03-10  0.833333     2.2      1402.00        88   8.997817
# 3 2004-03-10  0.875000     2.2      1375.50        80   9.228796
# 4 2004-03-10  0.916667     1.6      1272.25        51   6.518224
#
#    PT08.S2(NMHC)  NOx(GT)      predict  accuracy  PT08.S3(NOx)  NO2(GT)  \
# 0        1045.50    166.0  7415.878788  2.238440       1056.25    113.0
# 1         954.75    103.0  4619.060606  2.229891       1173.75     92.0
# 2         939.25    131.0  5862.090909  2.234698       1140.00    114.0
# 3         948.25    172.0  7682.242424  2.238930       1092.00    122.0
# 4         835.50    131.0  5862.090909  2.234698       1205.00    116.0
#
#    PT08.S4(NO2)  PT08.S5(O3)      T         RH        AH
# 0       1692.00      1267.50  13.60  48.875001  0.757754
# 1       1558.75       972.25  13.30  47.700000  0.725487
# 2       1554.50      1074.00  11.90  53.975000  0.750239
# 3       1583.75      1203.25  11.00  60.000000  0.786713
# 4       1490.00      1110.00  11.15  59.575001  0.788794

# %%
data.fillna(1)
# Out:
#            Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  \
# 0    2004-03-10  0.750000     2.6      1360.00       150  11.881723
# 1    2004-03-10  0.791667     2.0      1292.25       112   9.397165
# 2    2004-03-10  0.833333     2.2      1402.00        88   8.997817
# 3    2004-03-10  0.875000     2.2      1375.50        80   9.228796
# 4    2004-03-10  0.916667     1.6      1272.25        51   6.518224
# ...         ...       ...     ...          ...       ...        ...
# 9352 2005-04-04  0.416667     3.1      1314.25      -200  13.529605
# 9353 2005-04-04  0.458333     2.4      1162.50      -200  11.355157
# 9354 2005-04-04  0.500000     2.4      1142.00      -200  12.374538
# 9355 2005-04-04  0.541667     2.1      1002.50      -200   9.547187
# 9356 2005-04-04  0.583333     2.2      1070.75      -200  11.932060
#
#       PT08.S2(NMHC)  NOx(GT)      predict  accuracy  PT08.S3(NOx)  NO2(GT)  \
# 0           1045.50    166.0  7415.878788  2.238440       1056.25    113.0
# 1            954.75    103.0  4619.060606  2.229891       1173.75     92.0
# 2            939.25    131.0  5862.090909  2.234698       1140.00    114.0
# 3            948.25    172.0  7682.242424  2.238930       1092.00    122.0
# 4            835.50    131.0  5862.090909  2.234698       1205.00    116.0
# ...             ...      ...          ...       ...           ...      ...
# 9352        1101.25    471.7     1.000000  1.000000        538.50    189.8
# 9353        1027.00    353.3     1.000000  1.000000        603.75    179.2
# 9354        1062.50    293.0     1.000000  1.000000        603.25    174.7
# 9355         960.50    234.5     1.000000  1.000000        701.50    155.7
# 9356        1047.25    265.2     1.000000  1.000000        654.00    167.7
#
#       PT08.S4(NO2)  PT08.S5(O3)       T         RH        AH
# 0          1692.00      1267.50  13.600  48.875001  0.757754
# 1          1558.75       972.25  13.300  47.700000  0.725487
# 2          1554.50      1074.00  11.900  53.975000  0.750239
# 3          1583.75      1203.25  11.000  60.000000  0.786713
# 4          1490.00      1110.00  11.150  59.575001  0.788794
# ...            ...          ...     ...        ...       ...
# 9352       1374.25      1728.50  21.850  29.250000  0.756824
# 9353       1263.50      1269.00  24.325  23.725000  0.711864
# 9354       1240.75      1092.00  26.900  18.350000  0.640649
# 9355       1041.00       769.75  28.325  13.550000  0.513866
# 9356       1128.50       816.00  28.500  13.125000  0.502804
#
# [9357 rows x 17 columns]

# %%
mean=data['CO(GT)'].mean()

# %%
mean
# Out:
# -34.20752377898902

# %%
median=data['CO(GT)'].median()

# %%
median
# Out:
# 1.5

# %%
mode=data['CO(GT)'].mode()

# %%
mode
# Out:
# 0   -200.0
# dtype: float64

# %%
mean_data=data.groupby('CO(GT)')['NO2(GT)'].mean()

# %%
mean_data
# Out:
# CO(GT)
# -200.0   -122.407427
#  0.1       66.345455
#  0.2       33.653333
#  0.3        5.003061
#  0.4        2.786875
#              ...
#  9.9      269.000000
#  10.1     255.000000
#  10.2     209.500000
#  11.5     190.000000
#  11.9     220.000000
# Name: NO2(GT), Length: 97, dtype: float64

# %%
mean_data=data.groupby('CO(GT)')['NO2(GT)'].mean().rename("user_mean").reset_index()

# %%
mean_data
# Out:
#     CO(GT)   user_mean
# 0   -200.0 -122.407427
# 1      0.1   66.345455
# 2      0.2   33.653333
# 3      0.3    5.003061
# 4      0.4    2.786875
# ..     ...         ...
# 92     9.9  269.000000
# 93    10.1  255.000000
# 94    10.2  209.500000
# 95    11.5  190.000000
# 96    11.9  220.000000
#
# [97 rows x 2 columns]

# %%
final_data=data.merge(mean_data)

# %%
final_data
# Out:
#            Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)    C6H6(GT)  \
# 0    2004-03-10  0.750000     2.6      1360.00       150   11.881723
# 1    2004-03-13  0.958333     2.6      1418.00       116   10.873367
# 2    2004-03-16  0.916667     2.6      1379.25       183   13.529605
# 3    2004-03-17  0.583333     2.6      1389.25       152   13.735290
# 4    2004-03-17  0.958333     2.6      1488.00       216   15.710274
# ...         ...       ...     ...          ...       ...         ...
# 9352 2004-12-16  0.833333     9.1      -200.00      -200 -200.000000
# 9353 2004-12-23  0.833333     9.1      1701.00      -200   36.263240
# 9354 2004-12-23  0.750000     8.5      1629.50      -200   33.088098
# 9355 2005-02-11  0.666667     7.1      -200.00      -200 -200.000000
# 9356 2005-02-11  0.791667     7.1      -200.00      -200 -200.000000
#
#       PT08.S2(NMHC)  NOx(GT)      predict  accuracy  PT08.S3(NOx)  NO2(GT)  \
# 0           1045.50    166.0  7415.878788   2.23844       1056.25    113.0
# 1           1009.75    172.0          NaN       NaN        892.00    130.0
# 2           1101.25    184.0          NaN       NaN        817.50    138.0
# 3           1108.00    161.0          NaN       NaN        886.50    123.0
# 4           1170.75    178.0          NaN       NaN        731.00    127.0
# ...             ...      ...          ...       ...           ...      ...
# 9352        -200.00   1253.0          NaN       NaN       -200.00    219.0
# 9353        1691.75   1220.0          NaN       NaN        401.75    252.0
# 9354        1621.75   1089.0          NaN       NaN        421.00    247.0
# 9355        -200.00   1218.0          NaN       NaN       -200.00    339.7
# 9356        -200.00   1074.8          NaN       NaN       -200.00    289.0
#
#       PT08.S4(NO2)  PT08.S5(O3)        T          RH          AH   user_mean
# 0          1692.00      1267.50   13.600   48.875001    0.757754  118.462733
# 1          1603.00      1536.25   14.700   49.275001    0.819336  118.462733
# 2          1710.00      1601.75   17.925   45.900001    0.934186  118.462733
# 3          1711.50      1334.00   25.850   25.900000    0.850339  118.462733
# 4          1777.50      1705.00   16.025   50.924999    0.920599  118.462733
# ...            ...          ...      ...         ...         ...         ...
# 9352       -200.00      -200.00 -200.000 -200.000000 -200.000000  235.500000
# 9353       1831.75      2415.00    6.175   56.875000    0.541923  235.500000
# 9354       1757.25      2238.25    7.975   45.924999    0.493567  247.000000
# 9355       -200.00      -200.00 -200.000 -200.000000 -200.000000  314.350000
# 9356       -200.00      -200.00 -200.000 -200.000000 -200.000000  314.350000
#
# [9357 rows x 18 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model as lm

# %%
data
# Out:
#            Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  \
# 0    2004-03-10  0.750000     2.6      1360.00       150  11.881723
# 1    2004-03-10  0.791667     2.0      1292.25       112   9.397165
# 2    2004-03-10  0.833333     2.2      1402.00        88   8.997817
# 3    2004-03-10  0.875000     2.2      1375.50        80   9.228796
# 4    2004-03-10  0.916667     1.6      1272.25        51   6.518224
# ...         ...       ...     ...          ...       ...        ...
# 9352 2005-04-04  0.416667     3.1      1314.25      -200  13.529605
# 9353 2005-04-04  0.458333     2.4      1162.50      -200  11.355157
# 9354 2005-04-04  0.500000     2.4      1142.00      -200  12.374538
# 9355 2005-04-04  0.541667     2.1      1002.50      -200   9.547187
# 9356 2005-04-04  0.583333     2.2      1070.75      -200  11.932060
#
#       PT08.S2(NMHC)  NOx(GT)      predict  accuracy  PT08.S3(NOx)  NO2(GT)  \
# 0           1045.50    166.0  7415.878788  2.238440       1056.25    113.0
# 1            954.75    103.0  4619.060606  2.229891       1173.75     92.0
# 2            939.25    131.0  5862.090909  2.234698       1140.00    114.0
# 3            948.25    172.0  7682.242424  2.238930       1092.00    122.0
# 4            835.50    131.0  5862.090909  2.234698       1205.00    116.0
# ...             ...      ...          ...       ...           ...      ...
# 9352        1101.25    471.7          NaN       NaN        538.50    189.8
# 9353        1027.00    353.3          NaN       NaN        603.75    179.2
# 9354        1062.50    293.0          NaN       NaN        603.25    174.7
# 9355         960.50    234.5          NaN       NaN        701.50    155.7
# 9356        1047.25    265.2          NaN       NaN        654.00    167.7
#
#       PT08.S4(NO2)  PT08.S5(O3)       T         RH        AH
# 0          1692.00      1267.50  13.600  48.875001  0.757754
# 1          1558.75       972.25  13.300  47.700000  0.725487
# 2          1554.50      1074.00  11.900  53.975000  0.750239
# 3          1583.75      1203.25  11.000  60.000000  0.786713
# 4          1490.00      1110.00  11.150  59.575001  0.788794
# ...            ...          ...     ...        ...       ...
# 9352       1374.25      1728.50  21.850  29.250000  0.756824
# 9353       1263.50      1269.00  24.325  23.725000  0.711864
# 9354       1240.75      1092.00  26.900  18.350000  0.640649
# 9355       1041.00       769.75  28.325  13.550000  0.513866
# 9356       1128.50       816.00  28.500  13.125000  0.502804
#
# [9357 rows x 17 columns]

# %%
data1=data.head(5)

# %%
data1
# Out:
#         Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  \
# 0 2004-03-10  0.750000     2.6      1360.00       150  11.881723
# 1 2004-03-10  0.791667     2.0      1292.25       112   9.397165
# 2 2004-03-10  0.833333     2.2      1402.00        88   8.997817
# 3 2004-03-10  0.875000     2.2      1375.50        80   9.228796
# 4 2004-03-10  0.916667     1.6      1272.25        51   6.518224
#
#    PT08.S2(NMHC)  NOx(GT)      predict  accuracy  PT08.S3(NOx)  NO2(GT)  \
# 0        1045.50    166.0  7415.878788  2.238440       1056.25    113.0
# 1         954.75    103.0  4619.060606  2.229891       1173.75     92.0
# 2         939.25    131.0  5862.090909  2.234698       1140.00    114.0
# 3         948.25    172.0  7682.242424  2.238930       1092.00    122.0
# 4         835.50    131.0  5862.090909  2.234698       1205.00    116.0
#
#    PT08.S4(NO2)  PT08.S5(O3)      T         RH        AH
# 0       1692.00      1267.50  13.60  48.875001  0.757754
# 1       1558.75       972.25  13.30  47.700000  0.725487
# 2       1554.50      1074.00  11.90  53.975000  0.750239
# 3       1583.75      1203.25  11.00  60.000000  0.786713
# 4       1490.00      1110.00  11.15  59.575001  0.788794

# %%
plt.scatter(data1[['CO(GT)']],data1[['NO2(GT)']])

# %%
reg=lm.LinearRegression()

# %%
reg.fit(data1[['CO(GT)']],data1[['NO2(GT)']])
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([[3.33333333]])

# %%
reg.intercept_
# Out:
# array([104.33333333])

# %%
y_predict=reg.predict(data1[['NO2(GT)']])

# %%
y_predict
# Out:
# array([[481.        ],
#        [411.        ],
#        [484.33333333],
#        [511.        ],
#        [491.        ]])
